# %%
import os
from dotenv import load_dotenv
load_dotenv()  # this is used to load all the packages installed in env
# Out:
# True

# %%
# all these below import packages are been installed in pyproject.toml file when we ran the uv add ...
from langchain_groq import ChatGroq
llm = ChatGroq(model="llama-3.1-8b-instant", temperature=0)

# %%
from langchain_community.document_loaders import PyPDFLoader

pdf_path = "./Docs/rag.pdf"

loader = PyPDFLoader(pdf_path)
docs = loader.load()
# Out:
# /var/folders/24/m648p3m14t14qph9jqrr73h80000gn/T/ipykernel_5898/1530339283.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = text_splitter.split_documents(docs)

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
embedding_model = GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-001"
)

# %%
from langchain_community.vectorstores import FAISS # FAISS DB is a free vector store
vectorstore = FAISS.load_local("./Vector/", embedding_model, allow_dangerous_deserialization=True)

# %%
question = "what is transformer?"
context = vectorstore.similarity_search(question, k=2)

# %%
response = llm.invoke(f"Answer the question based on the following context: {context} question: {question}")
print(response.content)
# Out:
# The Transformer is a novel, simple network architecture proposed in the paper "Attention is All You Need" (2017) by Ashish Vaswani et al. It is a neural sequence transduction model that uses stacked self-attention and point-wise, fully connected layers for both the encoder and decoder, as shown in Figure 1.
#
# The Transformer architecture is designed to replace traditional recurrent neural networks (RNNs) and convolutional neural networks (CNNs) in sequence transduction tasks, such as machine translation. It is based solely on an attention mechanism, dispensing with recurrence and convolutions entirely.
#
# The Transformer model consists of an encoder and a decoder. The encoder maps an input sequence of symbol representations to a sequence of continuous representations, while the decoder generates an output sequence of symbols one element at a time. The model uses self-attention mechanisms to weigh the importance of different input elements when generating the output sequence.
#
# The Transformer architecture has several advantages over traditional models, including:
#
# * It is more parallelizable, allowing for faster training times.
# * It requires significantly less time to train.
# * It achieves superior quality in sequence transduction tasks, such as machine translation.
#
# The Transformer model has been widely adopted in natural language processing tasks, including machine translation, text summarization, and question answering.
